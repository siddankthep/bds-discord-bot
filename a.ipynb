# %%
top_10_holders = {
  "data": {
    "items": [
      {
        "amount": "4770072635892302",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "AVzP2GeRmqGphJsMxWoqjpUifPpCret7LqWhD8NWQK49",
        "token_account": "BUvduFTd2sWFagCunBPLupG8fBTJqweLw9DuhruNFSCm",
        "ui_amount": 4770072.635892302,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "605980089600561",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "9DrvZvyWh1HuAoZxvYWMvkf2XCzryCpGgHqrMjyDWpmo",
        "token_account": "GafNuUXj9rxGLn4y79dPu6MHSuPWeJR6UtTWuexpGh3U",
        "ui_amount": 605980.089600561,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "573113667620140",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "GugU1tP7doLeTw9hQP51xRJyS8Da1fWxuiy2rVrnMD2m",
        "token_account": "2nQNF8F9LLWMqdjymiLK2u8HoHMvYa4orCXsp3w65fQ2",
        "ui_amount": 573113.66762014,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "162068548014383",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "JCNCMFXo5M5qwUPg2Utu1u6YWp3MbygxqBsBeXXJfrw",
        "token_account": "DfYCNezifxAEsQbAJ1b3j6PX3JVBe8fu11KBhxsbw5d2",
        "ui_amount": 162068.548014383,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "150974434005990",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "AYhux5gJzCoeoc1PoJ1VxwPDe22RwcvpHviLDD1oCGvW",
        "token_account": "F2AETMoKjZgb3965ee9DiSriVmFDMA9Uf1ebuWuVzjUu",
        "ui_amount": 150974.43400599,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "126111702734362",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "Hp53XEtt4S8SvPCXarsLSdGfZBuUr5mMmZmX2DRNXQKp",
        "token_account": "F7tcS67EfP4bBJhWLxCk6ZmPVcsmPnJvPLQcDw5eeR67",
        "ui_amount": 126111.702734362,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "121766152660745",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1",
        "token_account": "5Zumc1SYPmQ89nqwXqzogeuhdJ85iEMpSk35A4P87pmD",
        "ui_amount": 121766.152660745,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "119811060289302",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "Dx8iy2o46sK1DzWbEcznqSKeLbLVeu7otkibA3WohGAj",
        "token_account": "ywaaLvG7t1vXJo8sT3UzE8yzzZtxLM7Fmev64Jbooye",
        "ui_amount": 119811.060289302,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "90185265914001",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "Czfq3xZZDmsdGdUyrNLtRhGc47cXcZtLG4crryfu44zE",
        "token_account": "EUuUbDcafPrmVTD5M6qoJAoyyNbihBhugADAxRMn5he9",
        "ui_amount": 90185.265914001,
        "is_scaled_ui_token": False,
        "multiplier": None
      },
      {
        "amount": "84675502151825",
        "decimals": 9,
        "mint": "So11111111111111111111111111111111111111112",
        "owner": "5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1",
        "token_account": "HiLcngHP5y1Jno53tuuNeFHKWhyyZp3XuxtKPszD6rG2",
        "ui_amount": 84675.502151825,
        "is_scaled_ui_token": False,
        "multiplier": None
      }
    ]
  },
  "success": True
}

# %%
total_supply = 118_471_642.80761878
test = 90_185_265_914_001
test_pct = round(test / total_supply, 2) * 100
print(test_pct)
top_10_holders_data = top_10_holders.get("data", {}).get("items", [])
top_10_holders_pct = [item.get("ui_amount", 0) / total_supply * 100 for item in top_10_holders_data]
top_10_holders_pct_str = [f"{pct:.2f}%" for pct in top_10_holders_pct]
top_10_holders_pct_str_formatted = "| ".join(top_10_holders_pct_str)
print(top_10_holders_pct_str_formatted)
# Out:
# 76123926.0
# 4.03%| 0.51%| 0.48%| 0.14%| 0.13%| 0.11%| 0.10%| 0.10%| 0.08%| 0.07%
